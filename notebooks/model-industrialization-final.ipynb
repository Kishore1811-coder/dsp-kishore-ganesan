# %% [markdown]
# # Model Industrialization Final

# %% [markdown]
# ## Model Building

# %%
from house_prices.train import build_model

model_performance_dict = build_model('../data/train.csv')
print(model_performance_dict)
# Out:
# {'rmsle': np.float64(0.2)}

# %% [markdown]
# ## Model Inference

# %%
from house_prices.inference import make_predictions

predictions = make_predictions('../data/test.csv')
predictions
# Out:
# array([117704.93616453, 159898.29933826, 195798.32808388, ...,
#        163789.92542465, 137423.42634231, 206011.60961339], shape=(1459,))
