# %%
import numpy as np
my_array = np.random.randint(0, 100, size=(10, 3))
display(my_array)
# Out:
# array([[42, 71, 90],
#        [54, 94, 17],
#        [26,  7, 68],
#        [ 8, 79, 21],
#        [57, 73, 95],
#        [14, 29, 22],
#        [39, 99, 14],
#        [ 4, 21, 80],
#        [73, 67, 48],
#        [54, 56, 66]])
